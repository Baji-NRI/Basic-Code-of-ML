# %% [markdown]
# <a href="https://colab.research.google.com/github/Baji-NRI/Basic-Code-of-ML/blob/main/Elements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Numbers = [10,20,30,40,50]
Numbers
Numbers[:]
Numbers[0:len(Numbers)]
# Out:
# [10, 20, 30, 40, 50]

# %%
numbers = [10,20,30,40,50]

numbers[0:5:2]
# Out:
# [10, 30, 50]

# %%
L1 = [10,20,30,50]
L1.append(40)
L1
# Out:
# [10, 20, 30, 50, 40]

# %%
L1 = [60,70,90,100]
L1.insert(2,80)
L1
# Out:
# [60, 70, 80, 90, 100]

# %%
L1 = [ 10,20,30,40]
L1.extend([44,50])
L1
# Out:
# [10, 20, 30, 40, 44, 50]

# %%
L1 = [ 10,20,30,40]
L1[2] = 60
L1
# Out:
# [10, 20, 60, 40]

# %%
L1 = [ 10,20,30,40]
L1.remove(30)
L1
# Out:
# [10, 20, 40]

# %%
L1 = [ 10,20,30,40]
L1.pop()
L1
# Out:
# [10, 20, 30]

# %%
L1 = [ 10,20,30,40,50]
L1.clear()
L1
# Out:
# []

# %%
L1 = [ 50,20,60,40]
L1.sort()
L1
# Out:
# [20, 40, 50, 60]

# %%
L1.reverse()
L1
# Out:
# [40, 30, 20, 10]

# %%
L1.clear()
L1
# Out:
# []
