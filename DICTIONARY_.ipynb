# %% [markdown]
# <a href="https://colab.research.google.com/github/Baji-NRI/Basic-Code-of-ML/blob/main/DICTIONARY_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Dictionary

d1 = {
     "Name" :"ABCD",
     "Age"  : 20,
     "Height" : 9.5,
}

# %% [markdown]
# # *set:-
#
# # set is an ordered collection of unique elements
#
# # *duplicates are not allowed
#
# # *no indexing
#
# # *mutable
#
# # *optimised membership testing

# %%
# creating a set
#{}
Set1 = {1,2,3,4,}

# %% [markdown]
# # newset = set ([List Name])

# %%
[10,20,30,40,30,40,50,60,10]
# Out:
# [10, 20, 30, 40, 30, 40, 50, 60, 10]

# %%
#Adding elements
set1 = {10,20,30}

# %%
#Adding single elements to set

Set1.add(40)
Set1
# Out:
# {1, 2, 3, 4, 40}

# %%
#Add multiple elements into a set

Set1.update([50,60,70,40,30])
Set1
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %%
#remove elements from a set
Set1.remove(40)
Set1
# Out:
# {10, 20, 30, 50, 60, 70}

# %%
#Remove elements from a set

Set1.discard(90)
Set1
# Out:
# {10, 20, 30, 50, 60, 70}

# %% [markdown]
# # error wise
#
# #1.possible - .remove (element)
# #2.not possible- .discard(elements)
# #Remove,discard,pop,clear

# %%
#set operators

A = {1,2,3}
B = {4,5,6}

# %% [markdown]
# #set operations:-
#
# #Union-> |
# #Intersection-> &
# #Difference-> -
# #Symmetric Difference-> ^

# %%
#union:-

A|B
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#intersection:-

A&B
# Out:
# set()

# %%
#Difference:-
A-B
# Out:
# {1, 2, 3}

# %%
#Symmetric difference
A^B
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#membership testing - very fast
#To check the presence of a element
5 in A
# Out:
# False

# %% [markdown]
# #*Tuple
#
# # #ordered but immutable collection
#
# # #Maintains order
#
# # #Allows duplicates
#
# # #Immutable
#
# # #uses less memory
#
# #faster than list

# %%
#creating a tuple
t1 = (10,20,30,40)
t2 = (50,)

# %%
#Access the elements
t1 [0]
t1 [-1]
t1 [1:3]
# Out:
# (20, 30)

# %%
#methods for tuples
t1.count (20)
# Out:
# 1

# %%
t1.index(30)
# Out:
# 2

# %%
#packing and unpacking
Data = (1,2,3)
A,B,C = Data

# %%
B
# Out:
# 2

# %% [markdown]
# # Functions:-
#
# # functions is a block of reusable code designed to perform a specific task
#
#
# #SIMPLE DEF:-
#
# # functions is a named block of code that runs only where it is called

# %% [markdown]
# #WHY WE NEED FUNCTIONS:-
#
# # 1.REDUCE CODE REPETITION
#
# # 2.improve readability
#
# # 3.make programs modular
#
# # 4.simplify debugging
#
# # 5.enable reuse across programs

# %% [markdown]
# # 1. built in functions - print,.upper,.lower
#
# # 2.user defined functions - new create
